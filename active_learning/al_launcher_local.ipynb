# %% [markdown]
# ## Initialization

# %%
from active_learning.al import AL
from utils.utils import get_tasks

# exp selection
# exp_name = 'acidic_mor_PtRuSc'
exp_name = 'ECSA_FeNiCo'
# exp_name = 'DFFC_PdPtCu'
# exp_name = 'acidic_oer_IrRuNi'
# exp_name = 'Thomas_battery_1'

# %% [markdown]
# |## Save and load

# %%
# load al instance from database
al = AL(exp_name)

# %%
# save the current al instance to the database
al.save_exp_to_db()

# %% [markdown]
# ## AL main workflow

# %% [markdown]
# ### recipe generation

# %%
# %%time
# generate next trial using Bayesian Optimization, specify beta if needed, e.g. beta=100 for exploration
al.generate_botorch_trial(n=1, beta = 0.2, aquisition = 'qUCB', optimizer_kwargs = {'options':{'maxiter':20000000}, 'sequential':True})
# Out:
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.models.torch.botorch_modular.model.BoTorchModel'>` expected argument `acquisition_options` to be of type typing.Optional[typing.Dict[str, typing.Any]]. Got {'beta': 0.2, 'aquisition': 'qUCB', 'optimizer_kwargs': {'options': {'maxiter': 20000000}, 'sequential': True}} (type: <class 'dict'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.models.torch.botorch_modular.model.BoTorchModel'>` expected argument `surrogate` to be of type typing.Optional[ax.models.torch.botorch_modular.surrogate.Surrogate]. Got <ax.models.torch.botorch_modular.surrogate.Surrogate object at 0x7f5390a0d7b0> (type: <class 'ax.models.torch.botorch_modular.surrogate.Surrogate'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `experiment` to be of type Experiment. Got Experiment(ECSA_FeNiCo) (type: <class 'ax.core.experiment.Experiment'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `search_space` to be of type SearchSpace. Got SearchSpace(parameters=[RangeParameter(name='Fe', parameter_type=FLOAT, range=[0.0, 1.0], digits=3), RangeParameter(name='Ni', parameter_type=FLOAT, range=[0.0, 1.0], digits=3)], parameter_constraints=[SumConstraint(Fe + Ni <= 1.0)]) (type: <class 'ax.core.search_space.SearchSpace'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `data` to be of type Data. Got <ax.core.data.Data object at 0x7f538f85ae90> (type: <class 'ax.core.data.Data'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `torch_device` to be of type Optional[torch.device]. Got cpu (type: <class 'torch.device'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `fit_out_of_design` to be of type bool. Got True (type: <class 'bool'>).
# [WARNING 02-11 12:54:59] ax.utils.common.kwargs: `<class 'ax.modelbridge.torch.TorchModelBridge'>` expected argument `default_model_gen_options` to be of type Optional[TConfig]. Got {'beta': 0.2, 'aquisition': 'qUCB', 'optimizer_kwargs': {'options': {'maxiter': 20000000}, 'sequential': True}} (type: <class 'dict'>).
# BO trial successfully added as trial 1
# CPU times: user 19.1 s, sys: 83.7 ms, total: 19.1 s
# Wall time: 5.48 s

# %%
# generate next trial using SOBOL method (random select)
al.generate_sobol_trial(n=15)

# %%
# update the recipe table on the database, if trial index is not specified, the recipe of the latest trial will be uploaded
al.update_recipe_table(trial_index=None, add_pred=False)

# %% [markdown]
# ### sample preparation

# %%
# benchmark specification
benchmark = None
# benchmark={5: '1_0'}

# %%
# command opentrons to prepare the sample for the latest trial, following the ot2_run_configs of the exp
al.make_sample(trial_index=None, benchmark=benchmark, operator_name='zhen')
# Out:
# *****IMPORTANT*****
# The sample id for the current batch is from 121 to 121
# *******************
# trial_arm_name_list ['1_0']
# tasks: Empty DataFrame
# Columns: [Fe, Ni, Co]
# Index: []
# OT2 detected via wired connection at 169.254.252.200!
#
#
# ***********task simulation passed***********
#
# starting experiment...
# /data/robot_settings.json not found. Loading defaults
# /data/deck_calibration.json not found. Loading defaults
# Moviepy - Building video /media/li/HDD/ot2_recordings/hyperlapse/2025-02-11 12-48-34_100x.mp4.
# Moviepy - Writing video /media/li/HDD/ot2_recordings/hyperlapse/2025-02-11 12-48-34_100x.mp4
# Moviepy - Done !
# Moviepy - video ready /media/li/HDD/ot2_recordings/hyperlapse/2025-02-11 12-48-34_100x.mp4

# %%
# update the sample table on the database, if trial index is not specified, the sample of the latest trial will be uploaded. Note that sample table calculation is based on local ot2_run_configs.py under project folder, not the one on ot2 server.
al.update_sample_table(trial_index=None, benchmark=benchmark)

# %% [markdown]
# ### sample testing complete

# %%
# run this cell after sample testing and data analysis is completed, then go back to the BO step
al.mark_trial_complete(trial_index=None)
# Out:
# BatchTrial(experiment_name='ECSA_FeNiCo', index=0, status=TrialStatus.RUNNING)

# %% [markdown]
# ## AL monitor

# %%
# update the exp with the latest result
al.update_exp_result()

# %%
# exp monitor for windows
al.exp_monitor()

# %%
# exp monitor for mac and linux
from IPython.display import display, HTML
display(HTML(al.exp_monitor().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>arm_name</th>
#       <th>trial_index</th>
#       <th>arm_index</th>
#       <th>Cr</th>
#       <th>Pd</th>
#       <th>Pt</th>
#       <th>Cu</th>
#       <th>Au</th>
#       <th>Ir</th>
#       <th>Ce</th>
#       <th>Nb</th>
#       <th>pred_mean</th>
#       <th>pred_std</th>
#       <th>max_power</th>
#       <th>trial_status</th>
#       <th>generation_method</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0_0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.382</td>
#       <td>0.202</td>
#       <td>0.020</td>
#       <td>0.007</td>
#       <td>0.095</td>
#       <td>0.056</td>
#       <td>0.146</td>
#       <td>0.092</td>
#       <td>30.850000</td>
#       <td>3.5810</td>
#       <td>30.88000</td>
#       <td>COMPLETED</td>
#       <td>Sobol</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0_1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.035</td>
#       <td>0.110</td>
#       <td>0.052</td>
#       <td>0.172</td>
#       <td>0.115</td>
#       <td>0.122</td>
#       <td>0.121</td>
#       <td>0.273</td>
#       <td>15.020000</td>
#       <td>3.2380</td>
#       <td>11.42000</td>
#       <td>COMPLETED</td>
#       <td>Sobol</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0_10</td>
#       <td>0</td>
#       <td>10</td>
#       <td>0.048</td>
#       <td>0.404</td>
#       <td>0.050</td>
#       <td>0.136</td>
#       <td>0.003</td>
#       <td>0.327</td>
#       <td>0.026</td>
#       <td>0.006</td>
#       <td>43.960000</td>
#       <td>3.9020</td>
#       <td>53.11000</td>
#       <td>COMPLETED</td>
#       <td>Sobol</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>
# 2   0.3053  0.2642  0.0292  0.0197  0.0000  0.1230  0.1547  0.1040
# 3   0.3372  0.1982  0.0037  0.0026  0.0579  0.2381  0.0000  0.1622
# 4   0.3130  0.2337  0.0235  0.0216  0.0000  0.2859  0.0969  0.0253
# 5   0.3368  0.1626  0.0259  0.2250  0.0806  0.0895  0.0796  0.0000
# 6   0.2964  0.1473  0.0080  0.0037  0.1068  0.2534  0.0000  0.1844
# 7   0.2801  0.0818  0.0185  0.1953  0.1038  0.1778  0.1427  0.0000
# 8   0.3781  0.1299  0.0000  0.0000  0.1842  0.2316  0.0280  0.0482
# 9   0.3012  0.1210  0.0247  0.3003  0.0177  0.0469  0.1883  0.0000
# 10  0.2797  0.0779  0.0201  0.3219  0.0787  0.1687  0.0531  0.0000
# 11  0.3507  0.1455  0.0545  0.0853  0.1589  0.1708  0.0000  0.0343
# 12  0.2696  0.2010  0.0527  0.1635  0.0000  0.1490  0.1548  0.0095
# 13  0.2703  0.1395  0.1028  0.0576  0.1136  0.2332  0.0001  0.0829
# 14  0.2691  0.1306  0.0232  0.1971  0.0987  0.2789  0.0024  0.0000
# 15  0.2905  0.0601  0.0172  0.2078  0.2017  0.1528  0.0698  0.0000
# 16  0.3246  0.0949  0.0105  0.1318  0.1435  0.2841  0.0106  0.0000
# 17  0.3021  0.2743  0.0866  0.1095  0.0009  0.1080  0.0971  0.0216
# 18  0.3077  0.1583  0.0000  0.0093  0.1658  0.2587  0.0505  0.0498
# 19  0.3166  0.1306  0.0463  0.0283  0.2349  0.2102  0.0000  0.0331
#
# Please double check task list as above
# manual trial successfully added as trial 16

# %%
# abandon an certain arm in a trial
al.abandon_arm(0, '0_18', 'abandoned in manual test')

# %%
# abandon a whole trial
al.abandon_trial(2, 'test trial')

# %% [markdown]
# ## Plotting

# %%
from ax.modelbridge.cross_validation import cross_validate
from ax.plot.contour import interact_contour
from ax.plot.diagnostic import interact_cross_validation
from ax.plot.scatter import interact_fitted
from ax.plot.slice import interact_slice
from ax.utils.notebook.plotting import render, init_notebook_plotting
init_notebook_plotting()

# %%
model = al.get_bo_model()

# %%
# Contour plots
render(interact_contour(model=model, metric_name='max_power'))

# %%
# Cross-validation plots
cv_results = cross_validate(model)
print('current r_squared is: ', al.calculate_r_squared(cv_results))
render(interact_cross_validation(cv_results))

# %%
# Slice plots
render(interact_slice(model))

# %%
# Tile plots
render(interact_fitted(model, rel=False))

# %% [markdown]
# ## Danger Zone

# %%
# delete the current active learning process from the database
al.delete_exp_on_db()

# %%
# only use this if you want to start a new experiment, note that the previous experiment has to be manually deleted, first, because the script refuses to overwrite the previous experiment by default
al = AL(exp_name, load_from_db=False)
# Out:
# Database ECSA_FeNiCo does not exist yet, creating now...
# Table recipe does not exist on server yet, creating now...
# Table sample does not exist on server yet, creating now...
# Table performance does not exist on server yet, creating now...
# full table view created
